# %%
import pandas as pd
import numpy as np
df1=pd.read_csv('Kenya Orders.csv')
df1.head(10)
# Out:
#    Order ID Order Status       Category Name         SKU  Customization Group  \
# 0  11265015      ORDERED   Cooking Fat & Oil    KKCO0487                  NaN
# 1  11264651      ORDERED  Cleaning & Hygiene  KKPT280100                  NaN
# 2  11264651      ORDERED       Flour & Sugar    KKFS0702                  NaN
# 3  11264651      ORDERED    Salt & Seasoning    KKSS0002                  NaN
# 4  11264651      ORDERED           Beverages    KKBE0105                  NaN
# 5  11264651      ORDERED   Cooking Fat & Oil    KKCO0310                  NaN
# 6  11264651      ORDERED  Cleaning & Hygiene   KKPT02501                  NaN
# 7  11264651      ORDERED    Salt & Seasoning    KKSS0205                  NaN
# 8  11264651      ORDERED       Flour & Sugar    KKFS0102                  NaN
# 9  11264651      ORDERED  Cleaning & Hygiene    KKPT0275                  NaN
#
#    Customization Option  Quantity  Unit Price Cost Price Total Cost Price  \
# ...

# %%
df2=pd.read_csv('Kenya Customers.csv')
#df2.head(10)

# %%
df3=pd.read_csv('Kenya Deliveries.csv')
df3.head()
# Out:
# C:\Users\BBES21062\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#      Task_ID       Order_ID  Relationship     Team_Name Task_Type  \
# 0  368110390  YR-11265216,0  3.681104e+29  Default Team  Delivery
# 1  368110390  YR-11265216,0  3.681104e+29  Default Team  Delivery
# 2  368109621  YR-11265175,0  3.681096e+29  Default Team  Delivery
# 3  368105817  YR-11265015,0  3.681058e+29  Default Team  Delivery
# 4  368098308  YR-11264651,0  3.680983e+29  Default Team  Delivery
#
#                                        Notes Agent_ID Agent_Name Distance(m)  \
# 0                                        NaN        -          -           -
# 1                                        NaN        -          -           -
# 2                                        NaN        -          -           -
# ...

# %%
df11=pd.read_csv('df1.csv')
df33=pd.read_csv('df3.csv')
# Out:
# C:\Users\BBES21062\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df11['OrderID']=df11['OrderID'].astype('str')
df33['OrderID']=df33['OrderID'].astype('str')

# %%
#dtale.show(df2)

# %%
import dtale
# Out:
# C:\Users\BBES21062\Anaconda3\lib\site-packages\dtale\dash_application\charts.py:13: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\BBES21062\Anaconda3\lib\site-packages\dtale\dash_application\charts.py:14: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
#dtale.show(df1)
#1.combine df1 and df3 based on ORDER ID

# %%
#dtale.show(df11)

# %%
#df11df33=pd.merge(df11,df33,on='OrderID')
df11df33=pd.merge(df11,df33,on='OrderID',how='outer')
#df11df33
#dtale.show(df11df33)
#df1.columns

# %%
df132=pd.merge(df11df33,df2,on='Customer ID',how='inner')
#dtale.show(df132)

# %%
dfn1=pd.read_csv('Nigeria Orders.csv')
dfn2=pd.read_csv('Nigeria Deliveries.csv')
dfn1['OrderID']=dfn1['OrderID'].astype('str')
dfn2['OrderID']=dfn2['OrderID'].astype('str')
#dtale.show(dfn1)

# %%
dfn1dfn2=pd.merge(dfn1,dfn2,on='OrderID',how='outer')
#dfn1dfn2

# %%
dfn3=pd.read_csv('Nigeria Customers.csv')

# %%
dfn123=pd.merge(dfn1dfn2,dfn3,on='Customer ID',how='outer')
#dfn123
#dtale.show(dfn123)

# %%
dfkn=pd.merge(df132,dfn123,on='Customer ID',how='outer')
#dtale.show(dfkn)

# %%
dfkn.isnull().mean()
# Out:
# OrderID_x                0.459108
# Order Status_x           0.459108
# Category Name_x          0.459373
# SKU_x                    0.459241
# Customization Group_x    1.000000
#                            ...
# Created At_y             0.895197
# Language_y               0.895197
# Outstanding Amount_y     0.895197
# Loyalty Points_y         0.895197
# Number of Employees      0.936199
# Length: 174, dtype: float64

# %%
dfkn.columns[dfkn.isnull().mean() < 0.5]
# Out:
# Index(['OrderID_x', 'Order Status_x', 'Category Name_x', 'SKU_x', 'Quantity_x',
#        'Unit Price_x', 'Cost Price_x', 'Total Cost Price_x', 'Total Price_x',
#        'Order Total_x', 'Sub Total_x', 'Tax_x', 'Delivery Charge_x', 'Tip_x_x',
#        'Discount_x_x', 'Remaining Balance_x', 'Payment Method_x',
#        'Additional Charge_x', 'Taxable Amount_x', 'Transaction ID_x',
#        'Currency Symbol_x', 'Customer ID', 'Merchant ID_x', 'Store Name_x',
#        'Pickup Address_x', 'Distance (in km)_x', 'Order Time_x',
#        'Pickup Time_x', 'Delivery Time_x', 'Order Preparation Time_x',
#        'Debt Amount', 'Redeemed Loyalty Points_x', 'Consumed Loyalty Points_x',
#        'Flat Discount_x', 'Checkout Template Name_x',
#        'Checkout Template Value_x', 'Last Used Platform_x', 'Is Blocked_x',
#        'Created At_x', 'Language_x', 'Outstanding Amount_x',
#        'Loyalty Points_x'],
#       dtype='object')

# %%
 dfs=dfkn[dfkn.columns[dfkn.isnull().mean() < 0.5]]
 dfs
# Out:
#       OrderID_x Order Status_x     Category Name_x       SKU_x  Quantity_x  \
# 0      11265015        ORDERED   Cooking Fat & Oil    KKCO0487         1.0
# 1      11213888      COMPLETED       Flour & Sugar   KKFS02350         1.0
# 2      10606303      CANCELLED   Cooking Fat & Oil    KKCO0487         1.0
# 3      10606303      CANCELLED  Cleaning & Hygiene    KKPT1201         1.0
# 4      11264651        ORDERED  Cleaning & Hygiene  KKPT280100         1.0
# ...         ...            ...                 ...         ...         ...
# 22628       NaN            NaN                 NaN         NaN         NaN
# 22629       NaN            NaN                 NaN         NaN         NaN
# 22630       NaN            NaN                 NaN         NaN         NaN
# 22631       NaN            NaN                 NaN         NaN         NaN
# 22632       NaN            NaN                 NaN         NaN         NaN
#
# ...

# %%
dfss=dfs.dropna()

# %%
dfss=dfss.drop(['Debt Amount', 'Transaction ID_x','Currency Symbol_x','Merchant ID_x','Store Name_x','Order Preparation Time_x','Checkout Template Name_x','Checkout Template Value_x','Flat Discount_x'], axis = 1)

# %%
dfss=dfss.drop(['Tax_x', 'Delivery Charge_x','Tip_x_x','Discount_x_x','Remaining Balance_x','Additional Charge_x','Taxable Amount_x',
'Last Used Platform_x','Is Blocked_x','Language_x','Outstanding Amount_x',], axis = 1)

# %%
#dtale.show(dfss)

# %%
dfss_s=dfss[dfss['Quantity_x']>=0]
dfss_s
# Out:
#       OrderID_x Order Status_x     Category Name_x       SKU_x  Quantity_x  \
# 0      11265015        ORDERED   Cooking Fat & Oil    KKCO0487         1.0
# 1      11213888      COMPLETED       Flour & Sugar   KKFS02350         1.0
# 2      10606303      CANCELLED   Cooking Fat & Oil    KKCO0487         1.0
# 3      10606303      CANCELLED  Cleaning & Hygiene    KKPT1201         1.0
# 4      11264651        ORDERED  Cleaning & Hygiene  KKPT280100         1.0
# ...         ...            ...                 ...         ...         ...
# 12237  10414449      COMPLETED   Cooking Fat & Oil    KKCO0411         1.0
# 12238  10413672      COMPLETED       Flour & Sugar    KKFS0902         1.0
# 12239  10413672      COMPLETED   Cooking Fat & Oil    KKCO0488         1.0
# 12240  10413630      CANCELLED       Flour & Sugar    KKFS0222         1.0
# 12241  10413630      CANCELLED   Cooking Fat & Oil    KKCO0488         1.0
#
# ...

# %%
dfss_s['Category Name_x']=dfss_s['Category Name_x'].str.split('&')

# %%
dfss_=dfss_s[['Customer ID','OrderID_x','Category Name_x','Loyalty Points_x','Order Time_x']]
dfss_
# Out:
#        Customer ID OrderID_x        Category Name_x  Loyalty Points_x  \
# 0        3755460.0  11265015   [Cooking Fat ,  Oil]              43.0
# 1        3755460.0  11213888       [Flour ,  Sugar]              43.0
# 2        3755460.0  10606303   [Cooking Fat ,  Oil]              43.0
# 3        3755460.0  10606303  [Cleaning ,  Hygiene]              43.0
# 4        4541187.0  11264651  [Cleaning ,  Hygiene]             145.0
# ...            ...       ...                    ...               ...
# 12237    4006884.0  10414449   [Cooking Fat ,  Oil]             333.0
# 12238    4021765.0  10413672       [Flour ,  Sugar]             168.0
# 12239    4021765.0  10413672   [Cooking Fat ,  Oil]             168.0
# 12240    4021765.0  10413630       [Flour ,  Sugar]             168.0
# 12241    4021765.0  10413630   [Cooking Fat ,  Oil]             168.0
#
#                    Order Time_x
# 0      2022-02-17T16:36:27.000Z
# 1      2022-02-14T18:12:21.000Z
# ...

# %%
my_basket=dfss_['Category Name_x']
len(my_basket)
# Out:
# 12233

# %%
def frequency_items (x,y):
    fx_=sum([x in i for i in my_basket])
    fy_=sum([y in i for i in my_basket])
    
    fxy_=sum([all(z in i for z in [x,y]) for i in my_basket])
    
    support=fxy_/len(my_basket)
    confidence = support/(fx_/len(my_basket))
    lift =confidence /(fy_/len(my_basket))
    if confidence ==1:
        conviction = 0
    else:
        conviction=(1-(fy_/len(my_basket)))/(1-confidence)
    
    print("Support = {}".format(round(support,2)))
    print("Confidence = {}".format(round(confidence,2)))
    print("Lift= {}".format(round(lift,2)))
    print("Conviction={}".format(round(conviction,2)))

# %%
#frequency_items('Cleaning','Hygiene')

# %%
import mlxtend.frequent_patterns 
import mlxtend.preprocessing

encode_=mlxtend.preprocessing.TransactionEncoder()
encode_arr=encode_.fit_transform(my_basket)

print(encode_arr)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
# Converting to Dataframe
encode_df=pd.DataFrame(encode_arr, columns=encode_.columns_)
encode_df
# Out:
#         Cereals   Fish   Hygiene    Oil   Seasoning   Sugar   Vegetables  \
# 0         False  False     False   True       False   False        False
# 1         False  False     False  False       False    True        False
# 2         False  False     False   True       False   False        False
# 3         False  False      True  False       False   False        False
# 4         False  False      True  False       False   False        False
# ...         ...    ...       ...    ...         ...     ...          ...
# 12228     False  False     False   True       False   False        False
# 12229     False  False     False  False       False    True        False
# 12230     False  False     False   True       False   False        False
# 12231     False  False     False  False       False    True        False
# 12232     False  False     False   True       False   False        False
#
#        Beverages  Cleaning   Cooking Fat   Flour   Fruits   Meat   Packaging  \
# ...

# %%
md=mlxtend.frequent_patterns.apriori(encode_df)
md_minsup=mlxtend.frequent_patterns.apriori(encode_df,
                                           min_support=0.01, 
                                            use_colnames=True)
md_minsup.head(20)
# Out:
#      support               itemsets
# 0   0.031391             ( Cereals)
# 1   0.037685                ( Fish)
# 2   0.077822             ( Hygiene)
# 3   0.243603                 ( Oil)
# 4   0.155072           ( Seasoning)
# 5   0.296902               ( Sugar)
# 6   0.075370          ( Vegetables)
# 7   0.022480            (Beverages)
# 8   0.077822            (Cleaning )
# 9   0.243603         (Cooking Fat )
# 10  0.296902               (Flour )
# 11  0.075370              (Fruits )
# 12  0.037685                (Meat )
# 13  0.057386            (Packaging)
# 14  0.031391                (Rice )
# 15  0.155072                (Salt )
# 16  0.031391      ( Cereals, Rice )
# 17  0.037685         (Meat ,  Fish)
# 18  0.077822  ( Hygiene, Cleaning )
# 19  0.243603   (Cooking Fat ,  Oil)

# %%
#Creating rules (Metric: Confidence) Antecedents ⇒ Consequents
rules=mlxtend.frequent_patterns.association_rules(
md_minsup, metric="confidence",min_threshold=0.06,support_only=False)

rules.head(20)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0       ( Cereals)         (Rice )            0.031391            0.031391
# 1          (Rice )      ( Cereals)            0.031391            0.031391
# 2          (Meat )         ( Fish)            0.037685            0.037685
# 3          ( Fish)         (Meat )            0.037685            0.037685
# 4       ( Hygiene)     (Cleaning )            0.077822            0.077822
# 5      (Cleaning )      ( Hygiene)            0.077822            0.077822
# 6   (Cooking Fat )          ( Oil)            0.243603            0.243603
# 7           ( Oil)  (Cooking Fat )            0.243603            0.243603
# 8          (Salt )    ( Seasoning)            0.155072            0.155072
# 9     ( Seasoning)         (Salt )            0.155072            0.155072
# 10        (Flour )        ( Sugar)            0.296902            0.296902
# ...

# %%
#Creating rules (Metric: Lift) Antecedents ⇒ Consequents
rules2=mlxtend.frequent_patterns.association_rules(
md_minsup, metric="lift",min_threshold=0.06,support_only=False)

rules2.head(20)
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 0       ( Cereals)         (Rice )            0.031391            0.031391
# 1          (Rice )      ( Cereals)            0.031391            0.031391
# 2          (Meat )         ( Fish)            0.037685            0.037685
# 3          ( Fish)         (Meat )            0.037685            0.037685
# 4       ( Hygiene)     (Cleaning )            0.077822            0.077822
# 5      (Cleaning )      ( Hygiene)            0.077822            0.077822
# 6   (Cooking Fat )          ( Oil)            0.243603            0.243603
# 7           ( Oil)  (Cooking Fat )            0.243603            0.243603
# 8          (Salt )    ( Seasoning)            0.155072            0.155072
# 9     ( Seasoning)         (Salt )            0.155072            0.155072
# 10        (Flour )        ( Sugar)            0.296902            0.296902
# ...

# %%
#Scatter plot
#Scatter plots help us to evaluate general tendencies of rules between antecedents and consequents.
import networkx as nx
import seaborn as sns
from matplotlib import pyplot as plt

# Generate scatterplot using support and confidence
plt.figure(figsize=(10,6))
sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules)
plt.margins(0.01,0.01)
plt.show()

# %%
#RFM analysis
#Recency: How recently has the customer made a transaction with us
#Frequency: How frequent is the customer in ordering/buying some product from us
#Monetary: How much does the customer spend on purchasing products from us.

# %%
dfss_['Order Time_x']= pd.to_datetime(dfss_['Order Time_x'])
# Out:
# <ipython-input-194-328b4cdc5976>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_recency = dfss_.groupby(by='Customer ID',
                        as_index=False)['Order Time_x'].max()
df_recency.columns = ['Customerid', 'LastPurchaseDate']
recent_date = df_recency['LastPurchaseDate'].max()
df_recency['Recency'] = df_recency['LastPurchaseDate'].apply(
    lambda x: (recent_date - x).days)
df_recency.head()
# Out:
#    Customerid          LastPurchaseDate  Recency
# 0   3365019.0 2022-02-11 20:02:56+00:00        5
# 1   3365770.0 2022-02-16 20:50:20+00:00        0
# 2   3377953.0 2022-02-08 10:18:44+00:00        9
# 3   3378262.0 2022-02-14 22:23:11+00:00        2
# 4   3385533.0 2022-02-12 10:21:45+00:00        5

# %%
frequency_df=dfss_['Customer ID'].value_counts()
freq_df=pd.DataFrame(frequency_df)
freq_df.rename(columns = {'Customer ID':'frequency'}, inplace = True)
freq_df.index.name='Customerid'
freq_df
# Out:
#             frequency
# Customerid
# 4696213.0         460
# 4026966.0         329
# 4669823.0         223
# 4593077.0         219
# 3636098.0         211
# ...               ...
# 4816504.0           1
# 4745877.0           1
# 4874970.0           1
# 4338381.0           1
# 4542972.0           1
#
# [550 rows x 1 columns]

# %%
#Monetery
dfss_s['Total'] = dfss_s['Sub Total_x']*dfss_s['Quantity_x']
monetary_df = dfss_s.groupby(by='Customer ID', as_index=False)['Total'].sum()
monetary_df.columns = ['Customerid', 'Monetary']
monetary_df.head()
# Out:
#    Customerid  Monetary
# 0   3365019.0   30384.0
# 1   3365770.0  272890.0
# 2   3377953.0  278503.0
# 3   3378262.0  334186.0
# 4   3385533.0   90099.0

# %%
#Merging all three columns in one dataframe


rf_df = df_recency.merge(freq_df, on='Customerid')
rfm_df = rf_df.merge(monetary_df, on='Customerid').drop(columns='LastPurchaseDate')
rfm_df.head()
# Out:
#    Customerid  Recency  frequency  Monetary
# 0   3365019.0        5          4   30384.0
# 1   3365770.0        0         44  272890.0
# 2   3377953.0        9          5  278503.0
# 3   3378262.0        2         26  334186.0
# 4   3385533.0        5         28   90099.0

# %%
#Ranking Customer’s based upon their recency, frequency, and monetary score
rfm_df['R_rank'] = rfm_df['Recency'].rank(ascending=False)
rfm_df['F_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['M_rank'] = rfm_df['Monetary'].rank(ascending=True)
 
# normalizing the rank of the customers
rfm_df['R_rank_norm'] = (rfm_df['R_rank']/rfm_df['R_rank'].max())*100
rfm_df['F_rank_norm'] = (rfm_df['F_rank']/rfm_df['F_rank'].max())*100
rfm_df['M_rank_norm'] = (rfm_df['F_rank']/rfm_df['M_rank'].max())*100
 
rfm_df.drop(columns=['R_rank', 'F_rank', 'M_rank'], inplace=True)
 
rfm_df.head(10)
# Out:
#    Customerid  Recency  frequency  Monetary  R_rank_norm  F_rank_norm  \
# 0   3365019.0        5          4   30384.0    60.623782    33.363636
# 1   3365770.0        0         44  272890.0   100.000000    87.454545
# 2   3377953.0        9          5  278503.0    46.881092    40.545455
# 3   3378262.0        2         26  334186.0    77.192982    79.727273
# 4   3385533.0        5         28   90099.0    60.623782    81.090909
# 5   3411830.0        3         10   37518.0    68.615984    57.818182
# 6   3417088.0        6          5   14799.0    56.627680    40.545455
# 7   3457559.0       34          2    4470.0    14.619883    12.454545
# 8   3472118.0       36          2    4338.0    10.526316    12.454545
# 9   3519514.0       27          1   16250.0    21.832359     3.181818
#
#    M_rank_norm
# 0    33.363636
# 1    87.454545
# 2    40.545455
# 3    79.727273
# 4    81.090909
# 5    57.818182
# 6    40.545455
# 7    12.454545
# 8    12.454545
# 9     3.181818

# %%
#Caluculating RFM score


rfm_df['RFM_Score'] = 0.15*rfm_df['R_rank_norm']+0.28 * \
    rfm_df['F_rank_norm']+0.57*rfm_df['M_rank_norm']
rfm_df['RFM_Score'] *= 0.05
rfm_df = rfm_df.round(2)
rfm_df[['Customerid', 'RFM_Score']].head(7)
# Out:
#    Customerid  RFM_Score
# 0   3365019.0       1.87
# 1   3365770.0       4.47
# 2   3377953.0       2.07
# 3   3378262.0       3.97
# 4   3385533.0       3.90
# 5   3411830.0       2.97
# 6   3417088.0       2.15

# %%
#Rating Customer based upon the RFM score
#rfm score >4.5 : Top Customer
#4.5 > rfm score > 4 : High Value Customer
#4>rfm score >3 : Medium value customer
#3>rfm score>1.6 : Low-value customer
#rfm score<1.6 :Lost Customer

# %%
rfm_df["Customer_segment"] = np.where(rfm_df['RFM_Score'] >
                                      4.5, "Top Customers",
                                      (np.where(
                                        rfm_df['RFM_Score'] > 4,
                                        "High value Customer",
                                        (np.where(
    rfm_df['RFM_Score'] > 3,
                             "Medium Value Customer",
                             np.where(rfm_df['RFM_Score'] > 1.6,
                            'Low Value Customers', 'Lost Customers'))))))
rfm_df[['Customerid', 'RFM_Score', 'Customer_segment']].head(20)
# Out:
#     Customerid  RFM_Score       Customer_segment
# 0    3365019.0       1.87    Low Value Customers
# 1    3365770.0       4.47    High value Customer
# 2    3377953.0       2.07    Low Value Customers
# 3    3378262.0       3.97  Medium Value Customer
# 4    3385533.0       3.90  Medium Value Customer
# 5    3411830.0       2.97    Low Value Customers
# 6    3417088.0       2.15    Low Value Customers
# 7    3457559.0       0.64         Lost Customers
# 8    3472118.0       0.61         Lost Customers
# 9    3519514.0       0.30         Lost Customers
# 10   3553157.0       3.07  Medium Value Customer
# 11   3554524.0       1.18         Lost Customers
# 12   3555286.0       0.19         Lost Customers
# 13   3636098.0       4.97          Top Customers
# 14   3647723.0       4.80          Top Customers
# 15   3648386.0       4.88          Top Customers
# 16   3648474.0       0.17         Lost Customers
# 17   3648607.0       4.72          Top Customers
# ...

# %%
#Visualizing the customer segments
plt.pie(rfm_df.Customer_segment.value_counts(),
        labels=rfm_df.Customer_segment.value_counts().index,
        autopct='%.0f%%')
plt.show()
# Out:
# <ipython-input-192-caee2df64e79>:5: UserWarning:
#
# Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
# Thank you.
